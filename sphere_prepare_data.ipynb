# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')
import math
import os

# %%
all_df = pd.DataFrame()
all_files = os.listdir(".\\data\\")
for file in all_files:
    df = pd.read_csv(".\\data\\"+file)
    print(df.shape)
    all_df = pd.concat([all_df, df])
    
all_df.dropna(axis=0,subset=['a_ascend'],inplace=True)
all_df.shape
# Out:
# (1760, 130)
# (1779, 130)
# (1656, 130)
# (1520, 130)
# (1539, 130)
# (1507, 130)
# (1392, 130)
# (1505, 130)
# (1669, 130)
# (1825, 130)
# (16124, 130)

# %%
import missingno as msno
msno.matrix(all_df)
